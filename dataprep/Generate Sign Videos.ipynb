# %%
# !conda install -y ffmpeg
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import concurrent
from collections import namedtuple
import os
import zipfile
import shutil
from getpass import getpass
import datetime
from itertools import repeat

import boto3
import requests
import pandas as pd
import subprocess

# %%
CHECKPOINTS_DIR = "checkpoints/"
POSE_DIR = "v2/data/raw/gloss2pose/poses/"
VIDEO_DOWNLOAD_DIR = "v2/data/raw/gloss2pose/signs/"
VIDEO_METADATA_FILE = "v2/data/metadata/video_metadata.csv"
UNFORMATTED_URL = "http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/{session}/scene{scene}-camera1.mov"
S3_BUCKET= "genasl-avatar"  #replacce with your bucket name
TABLE_NAME="Pose_Data7"
partition_id = 0
number_partitions = 1
S3_LOOKUP_FOLDER = "v2/gloss2pose/lookup/"
DATA_DIR=os.getcwd()
FRAME_RATE=30

# %%
class VideoSegmentMetadata(object):
    def __init__(self, segment_id, start_frame, end_frame,gloss):
        self.segment_id = segment_id
        self.start_frame = start_frame
        self.end_frame = end_frame
        self.gloss = gloss

class VideoMetadata(object):

    def __init__(self, video_id, url, session, scene, segments_metadata):
        self.video_id = video_id
        self.url = url
        self.session = session
        self.scene = scene
        self.segments_metadata = segments_metadata

def time_print(string):
    now = datetime.datetime.now()
    return print("{}: {}".format(now, string))

# taken from https://stackoverflow.com/questions/1855095/how-to-create-a-zip-archive-of-a-directory-in-python
def zip_dir(directory, zipped_filepath):
    # ziph is zipfile handle
    ziph = zipfile.ZipFile(zipped_filepath, 'w', zipfile.ZIP_DEFLATED)
    for root, dirs, files in os.walk(directory):
        for filename in files:
            ziph.write(os.path.join(root, filename))

    return zipped_filepath

def get_video_metadata(bucket, s3_filepath, download_filepath, partition, num_partitions):
    print(s3_filepath)
    os.makedirs(os.path.dirname(download_filepath), exist_ok=True)
    bucket.download_file(s3_filepath, download_filepath)
    metadata = pd.read_csv(s3_filepath)
    print(metadata)
    metadata = metadata[metadata["session_scene_id"] % num_partitions == partition]
    # Remove corrupt segments
    metadata = metadata[metadata["is_corrupt"] == 0]
    #Keep only Liz videos
    metadata = metadata[metadata["Consultant"] == "Liz"]
    collapsed_metadata = metadata[["session_scene_id", "Session", "Scene"]].drop_duplicates().sort_values(by=["session_scene_id"])
    collapsed_metadata.index = collapsed_metadata["session_scene_id"]
    metadata["id-start-end-gloss"] = metadata["id"].apply(str) + "$" + \
                                     metadata["Start"].apply(str) + "$" +\
                                     metadata["End"].apply(str) + "$"+ \
                                     metadata["Gloss Variant"]
    frames_info = metadata.groupby(["session_scene_id"])["id-start-end-gloss"].apply(list)
    collapsed_metadata = pd.concat([collapsed_metadata, frames_info], axis=1)
    return [
        VideoMetadata(
            value[0],
            UNFORMATTED_URL.format(
                session=value[1],
                scene=value[2]
            ),
            value[1],
            value[2],
            sorted([
                VideoSegmentMetadata(
                    segment_id=int(segment.split("$")[0]),
                    start_frame=int(segment.split("$")[1]),
                    end_frame=int(segment.split("$")[2]),
                    gloss=segment.split("$")[3]
                ) for segment in value[3]
            ], key=lambda x: x.start_frame)
        ) for value in collapsed_metadata.values
    ]


def process_video(video,checkpoint_video_id):
    # Skip all videos with id <= checkpoint_video_id
    # If checkpoint_video_id isn't found, raise an Exception
    if checkpoint_video_id is None:
        pass
    elif checkpoint_video_id > video.video_id:
        return
    elif checkpoint_video_id == video.video_id:
        checkpoint_video_id = None
        return
    else:
        raise Exception(
            "Checkpoint video_id {} not valid".format(checkpoint_video_id)
        )
    time_print("Downloading {} with video_id {}".format(video.url, video.video_id))
    download_dir = os.path.join(DATA_DIR, VIDEO_DOWNLOAD_DIR)
    video_filepath = download_large_file(
        video.url,
        download_dir,
        "{}-{}.{}".format(
            video.session,
            video.scene,
            video.url.split(".")[-1]
        )
    )
    for segment in video.segments_metadata:
        time_print("Processing video segment {}".format(
            segment.segment_id
        ))
        temp_segment_filepath = clip_video(
            video_filepath,
            os.path.join(
                download_dir,
                "temp-segment-{}.mov".format(segment.segment_id)
            ),
            segment.start_frame,
            segment.end_frame,
        )

        segment_filepath = resample_video(
            temp_segment_filepath,
            os.path.join(
                download_dir,
                "sign-{}.mp4".format(segment.segment_id)
            ),
           FRAME_RATE
        )

        if os.path.exists(segment_filepath):
              bucket.upload_file(
                segment_filepath,
                os.path.join(
                    S3_LOOKUP_FOLDER,
                    "sign/",
                    os.path.basename(segment_filepath)
                )
            )

        if os.path.exists(temp_segment_filepath):
              bucket.upload_file(
                temp_segment_filepath,
                os.path.join(
                    S3_LOOKUP_FOLDER,
                    "rawsign/",
                    os.path.basename(temp_segment_filepath)
                )
            )

        gloss=segment.gloss.upper()
        for g in gloss.split('/'):
            g=g.replace('+','')
            g=g.replace('#','')
            response = table.put_item(
                Item={
                    'Gloss': g,
                    'SignID': segment.segment_id
                }
            )


        # Clean up
        os.remove(temp_segment_filepath)
        if os.path.exists(segment_filepath):
            os.remove(segment_filepath)

    # Update checkpoint after processing entire video
    checkpoint = s3.Object(S3_BUCKET, checkpoint_filepath)
    checkpoint.put(Body=r'{}'.format(video.video_id))
    os.remove(video_filepath)

# %%
##utils


from collections import namedtuple
import os
import zipfile
import shutil
from getpass import getpass
import datetime

import boto3
import requests
import pandas as pd


def run_bash_cmd(cmd,dir=None):
    result=subprocess.run(cmd, shell=True,  cwd=dir,capture_output=True, text=True)
    

def zip_dir(directory, zipped_filepath):
    # ziph is zipfile handle
    ziph = zipfile.ZipFile(zipped_filepath, 'w', zipfile.ZIP_DEFLATED)
    for root, dirs, files in os.walk(directory):
        for filename in files:
            ziph.write(os.path.join(root, filename))

    return zipped_filepath

def clip_video(from_video_filepath, to_video_filepath, start_frame, end_frame):

    """
    create video clip starting at @start_frame and ending at @end_frame inclusive
    """

    unformatted_cmd = "ffmpeg -i {from_path} -vf trim=start_frame={start_frame}:end_frame={end_frame} -y -an {to_path}"

    cmd = unformatted_cmd.format(
        from_path=from_video_filepath,
        to_path=to_video_filepath,
        start_frame=start_frame,
        end_frame=end_frame + 1,
    )

    run_bash_cmd(cmd)

    return to_video_filepath

def resample_video(from_video_filepath, to_video_filepath, frame_rate):
    """
    resamples video with @frame_rate and outputs new video
    """

    unformatted_cmd = "ffmpeg -i {from_path} -filter:v fps={frame_rate} -q:v 0 -vcodec h264  -y {to_path}"

    cmd = unformatted_cmd.format(
        from_path=from_video_filepath,
        to_path=to_video_filepath,
        frame_rate=frame_rate,
    )


    run_bash_cmd(cmd)



    return to_video_filepath



# taken from https://stackoverflow.com/questions/16694907/download-large-file-in-python-with-requests
def download_large_file(url, download_dir, filename):
    os.makedirs(download_dir, exist_ok=True)
    local_filename = os.path.join(download_dir, filename)
    with requests.get(url, stream=True) as response:
        with open(local_filename, 'wb') as file_obj:
            shutil.copyfileobj(response.raw, file_obj)

    return local_filename

def write_concat_input_file(video_filepaths, input_filepath):

    with open(input_filepath, "w") as file_obj:
        for filepath in video_filepaths:
            file_obj.write("file '{}'\n".format(filepath))

    return input_filepath

def download_pose_files(bucket, s3_lookup_folder, download_directory, pose_ids):
    pose_filepaths = []
    for pose_id in pose_ids:
        pose_filename = "pose-{}.mov".format(pose_id)
        pose_filepath = os.path.join(download_directory, pose_filename)
        bucket.download_file(
            os.path.join(
                s3_lookup_folder,
                pose_filename
            ),
            pose_filepath
        )
        pose_filepaths.append(pose_filepath)

    return pose_filepaths

def images_to_video(image_filepaths, video_filepath):
    """
    creates video from directory of images
    """


    unformatted_cmd = "ffmpeg -r 30 -f image2 -s 400x336 -i {image_filepaths} -vcodec libx264 -crf 25  -pix_fmt yuv420p {video_filepath}"

    cmd = unformatted_cmd.format(
        image_filepaths=image_filepaths,
        video_filepath=video_filepath,
    )

    run_bash_cmd(cmd)

    return video_filepath


def video_to_jpg(video_filepath, jpg_directory):
    """
    create video clip starting at @start_frame and ending at @end_frame inclusive
    """


    unformatted_cmd = "ffmpeg -i {} {} -hide_banner"

    cmd = unformatted_cmd.format(
        video_filepath,
        os.path.join(jpg_directory, "video-%06d.jpg")
    )

    run_bash_cmd(cmd)

    return jpg_directory

def jpg_to_png(jpg_directory, png_directory):

    unformatted_cmd = "mogrify -format png -path {} {}"

    cmd = unformatted_cmd.format(
        png_directory,
        os.path.join(jpg_directory, "*.jpg")
    )

    run_bash_cmd(cmd)

    return png_directory

def concat_videos(video_filepaths, output_filepath):

    """
    create video clip starting at @start_frame and ending at @end_frame inclusive
    """

    input_filepath = os.path.join(
        os.path.dirname(video_filepaths[0]),
        "input.txt"
    )

    video_filenames = [os.path.basename(f) for f in video_filepaths]
    write_concat_input_file(video_filenames, input_filepath)

    unformatted_cmd = "ffmpeg -f concat -safe 0 -i {} -codec copy -y {}"

    cmd = unformatted_cmd.format(
        input_filepath,
        output_filepath
    )

    run_bash_cmd(cmd)

    return output_filepath

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket(S3_BUCKET)

dynamodb = boto3.resource('dynamodb')
table = dynamodb.Table(TABLE_NAME)


# If the bucket doesn't exist, create it
if not bucket.creation_date:
    bucket = s3.create_bucket(
        Bucket=S3_BUCKET,
        CreateBucketConfiguration={'LocationConstraint': boto3.session.Session().region_name}
    )

checkpoint_filename = "partition-{}-of-{}.txt".format(
    partition_id,
    number_partitions
)

checkpoint_filepath = os.path.join(
    S3_LOOKUP_FOlDER,
    CHECKPOINTS_DIR,
    checkpoint_filename
)

try:
    checkpoint_video_id = s3.Object(
        S3_BUCKET, checkpoint_filepath
    ).get()['Body'].read().decode('utf-8')
    checkpoint_video_id = int(checkpoint_video_id)
except s3.meta.client.exceptions.NoSuchKey:
    checkpoint_video_id = None

video_metadata_filepath = os.path.join(
        DATA_DIR,
        VIDEO_METADATA_FILE
    )

videos = get_video_metadata(
    bucket, VIDEO_METADATA_FILE, video_metadata_filepath,
    partition_id, number_partitions
)
for video in videos:
    process_video(video,checkpoint_video_id)

# with concurrent.futures.ThreadPoolExecutor(max_workers=1) as executor:
#     executor.map(process_video,videos,repeat(checkpoint_video_id))
# Out:
# v2/data/metadata/video_metadata.csv
#                 Main New Gloss.1               Gloss Variant Consultant  \
# 0                          False                       False      Tyler
# 1                          False                      FALSE+      Brady
# 2                          False                      FALSE+      Brady
# 3                          False                      FALSE+      Brady
# 4                          False                      FALSE+        Liz
# ...                          ...                         ...        ...
# 9758            ns-nat-SRI-LANKA            ns-nat-SRI-LANKA        Liz
# 9759             ns-nat-THAILAND             ns-nat-THAILAND      Brady
# 9760             ns-nat-THAILAND             ns-nat-THAILAND        Liz
# 9761  ns-nat-TRINIDAD-AND-TOBAGO  ns-nat-TRINIDAD-AND-TOBAGO      Brady
# 9762  ns-nat-TRINIDAD-AND-TOBAGO  ns-nat-TRINIDAD-AND-TOBAGO        Liz
#
#                    Session  Scene  Start   End    id  \
# 0          ASL_2008_05_29a     18    560   585     0
# 1     ASL_2011_06_08_Brady     13   4090  4115     1
# 2     ASL_2011_06_14_Brady     15   8090  8129     2
# 3     ASL_2011_06_14_Brady     17   4601  4630     3
# 4           ASL_2008_01_18     38    662   702     4
# ...                    ...    ...    ...   ...   ...
# 9758        ASL_2008_02_29     42   1812  1865  9758
# 9759  ASL_2011_07_19_Brady    112   2104  2122  9759
# 9760        ASL_2008_03_28      8   1495  1525  9760
# 9761  ASL_2011_07_22_Brady     11   1586  1636  9761
# 9762        ASL_2008_03_28     23    505   567  9762
#
#                  session_scene  session_scene_id  is_corrupt  \
# 0           ASL_2008_05_29a-18               455           0
# 1      ASL_2011_06_08_Brady-13               722           0
# 2      ASL_2011_06_14_Brady-15               758           0
# 3      ASL_2011_06_14_Brady-17               760           0
# 4            ASL_2008_01_18-38               157           0
# ...                        ...               ...         ...
# 9758         ASL_2008_02_29-42               316           0
# 9759  ASL_2011_07_19_Brady-112               817           0
# 9760          ASL_2008_03_28-8               376           0
# 9761   ASL_2011_07_22_Brady-11               902           0
# 9762         ASL_2008_03_28-23               345           0
#
#                   Main New Gloss
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 9758            ns-nat-SRI-LANKA
# 9759             ns-nat-THAILAND
# 9760             ns-nat-THAILAND
# 9761  ns-nat-TRINIDAD-AND-TOBAGO
# 9762  ns-nat-TRINIDAD-AND-TOBAGO
#
# [9763 rows x 12 columns]
# 2024-04-09 19:00:36.501274: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene10-camera1.mov with video_id 45
# 2024-04-09 19:00:37.373785: Processing video segment 159
# 2024-04-09 19:00:37.984081: Processing video segment 8502
# 2024-04-09 19:00:38.653968: Processing video segment 460
# 2024-04-09 19:00:39.384676: Processing video segment 9211
# 2024-04-09 19:00:40.262756: Processing video segment 470
# 2024-04-09 19:00:41.085794: Processing video segment 477
# 2024-04-09 19:00:42.023026: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene11-camera1.mov with video_id 46
# 2024-04-09 19:00:44.162184: Processing video segment 855
# 2024-04-09 19:00:44.767141: Processing video segment 492
# 2024-04-09 19:00:45.386145: Processing video segment 497
# 2024-04-09 19:00:46.104956: Processing video segment 7468
# 2024-04-09 19:00:46.801205: Processing video segment 501
# 2024-04-09 19:00:47.664267: Processing video segment 509
# 2024-04-09 19:00:48.485704: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene12-camera1.mov with video_id 47
# 2024-04-09 19:00:49.610396: Processing video segment 12
# 2024-04-09 19:00:50.014615: Processing video segment 514
# 2024-04-09 19:00:50.596062: Processing video segment 519
# 2024-04-09 19:00:51.136844: Processing video segment 3040
# 2024-04-09 19:00:51.737635: Processing video segment 294
# 2024-04-09 19:00:52.412285: Processing video segment 8649
# 2024-04-09 19:00:53.344718: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene13-camera1.mov with video_id 48
# 2024-04-09 19:00:55.975519: Processing video segment 541
# 2024-04-09 19:00:56.637221: Processing video segment 451
# 2024-04-09 19:00:57.311296: Processing video segment 9402
# 2024-04-09 19:00:58.123748: Processing video segment 548
# 2024-04-09 19:00:59.067283: Processing video segment 8700
# 2024-04-09 19:01:00.049608: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene14-camera1.mov with video_id 49
# 2024-04-09 19:01:01.345911: Processing video segment 9653
# 2024-04-09 19:01:01.922608: Processing video segment 550
# 2024-04-09 19:01:02.540176: Processing video segment 4174
# 2024-04-09 19:01:03.384780: Processing video segment 556
# 2024-04-09 19:01:04.119482: Processing video segment 561
# 2024-04-09 19:01:04.889546: Processing video segment 568
# 2024-04-09 19:01:05.849786: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene15-camera1.mov with video_id 50
# 2024-04-09 19:01:06.619296: Processing video segment 575
# 2024-04-09 19:01:07.075181: Processing video segment 6610
# 2024-04-09 19:01:07.561804: Processing video segment 582
# 2024-04-09 19:01:08.160164: Processing video segment 591
# 2024-04-09 19:01:08.808167: Processing video segment 595
# 2024-04-09 19:01:09.578332: Processing video segment 600
# 2024-04-09 19:01:10.590419: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene16-camera1.mov with video_id 51
# 2024-04-09 19:01:11.168888: Processing video segment 605
# 2024-04-09 19:01:11.715245: Processing video segment 6958
# 2024-04-09 19:01:12.253176: Processing video segment 2506
# 2024-04-09 19:01:12.896459: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene18-camera1.mov with video_id 52
# 2024-04-09 19:01:14.362166: Processing video segment 628
# 2024-04-09 19:01:15.056918: Processing video segment 633
# 2024-04-09 19:01:15.802580: Processing video segment 8989
# 2024-04-09 19:01:16.615709: Processing video segment 634
# 2024-04-09 19:01:17.554492: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene19-camera1.mov with video_id 53
# 2024-04-09 19:01:18.671305: Processing video segment 638
# 2024-04-09 19:01:19.275984: Processing video segment 641
# 2024-04-09 19:01:20.018581: Processing video segment 647
# 2024-04-09 19:01:20.910846: Processing video segment 4521
# 2024-04-09 19:01:21.820175: Processing video segment 4184
# 2024-04-09 19:01:22.879941: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene2-camera1.mov with video_id 54
# 2024-04-09 19:01:24.623252: Processing video segment 3652
# 2024-04-09 19:01:25.115493: Processing video segment 3998
# 2024-04-09 19:01:25.608758: Processing video segment 8558
# 2024-04-09 19:01:26.136114: Processing video segment 8807
# 2024-04-09 19:01:26.789870: Processing video segment 3180
# 2024-04-09 19:01:27.521948: Processing video segment 6534
# 2024-04-09 19:01:28.218431: Processing video segment 8455
# 2024-04-09 19:01:29.097568: Processing video segment 3984
# 2024-04-09 19:01:30.036056: Processing video segment 8572
# 2024-04-09 19:01:31.059692: Processing video segment 8812
# 2024-04-09 19:01:32.159936: Processing video segment 6388
# 2024-04-09 19:01:33.434257: Processing video segment 6382
# 2024-04-09 19:01:34.622174: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene20-camera1.mov with video_id 55
# 2024-04-09 19:01:35.506767: Processing video segment 654
# 2024-04-09 19:01:36.087590: Processing video segment 665
# 2024-04-09 19:01:36.839525: Processing video segment 258
# 2024-04-09 19:01:37.693916: Processing video segment 7801
# 2024-04-09 19:01:38.630417: Processing video segment 6873
# 2024-04-09 19:01:39.748466: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene21-camera1.mov with video_id 56
# 2024-04-09 19:01:40.319105: Processing video segment 4531
# 2024-04-09 19:01:40.913766: Processing video segment 8127
# 2024-04-09 19:01:41.510895: Processing video segment 9411
# 2024-04-09 19:01:42.100119: Processing video segment 659
# 2024-04-09 19:01:42.838831: Processing video segment 6601
# 2024-04-09 19:01:43.815531: Processing video segment 673
# 2024-04-09 19:01:44.662725: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene22-camera1.mov with video_id 57
# 2024-04-09 19:01:45.251683: Processing video segment 682
# 2024-04-09 19:01:45.880118: Processing video segment 9144
# 2024-04-09 19:01:46.471760: Processing video segment 695
# 2024-04-09 19:01:47.204079: Processing video segment 535
# 2024-04-09 19:01:47.830646: Processing video segment 7740
# 2024-04-09 19:01:48.575474: Processing video segment 173
# 2024-04-09 19:01:49.551682: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene23-camera1.mov with video_id 58
# 2024-04-09 19:01:51.716688: Processing video segment 9416
# 2024-04-09 19:01:52.434290: Processing video segment 7344
# 2024-04-09 19:01:52.942810: Processing video segment 18
# 2024-04-09 19:01:53.447088: Processing video segment 709
# 2024-04-09 19:01:54.093664: Processing video segment 8023
# 2024-04-09 19:01:54.818187: Processing video segment 714
# 2024-04-09 19:01:55.610871: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene24-camera1.mov with video_id 59
# 2024-04-09 19:01:56.818918: Processing video segment 9418
# 2024-04-09 19:01:57.323585: Processing video segment 9422
# 2024-04-09 19:01:57.916097: Processing video segment 721
# 2024-04-09 19:01:58.503281: Processing video segment 4296
# 2024-04-09 19:01:59.105712: Processing video segment 4299
# 2024-04-09 19:01:59.723436: Processing video segment 6737
# 2024-04-09 19:02:00.531144: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene25-camera1.mov with video_id 60
# 2024-04-09 19:02:01.944156: Processing video segment 726
# 2024-04-09 19:02:02.494469: Processing video segment 6771
# 2024-04-09 19:02:03.318093: Processing video segment 738
# 2024-04-09 19:02:04.173570: Processing video segment 735
# 2024-04-09 19:02:05.062932: Processing video segment 743
# 2024-04-09 19:02:05.944995: Processing video segment 9426
# 2024-04-09 19:02:06.800697: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene26-camera1.mov with video_id 61
# 2024-04-09 19:02:09.377079: Processing video segment 9656
# 2024-04-09 19:02:09.906749: Processing video segment 9660
# 2024-04-09 19:02:10.529401: Processing video segment 747
# 2024-04-09 19:02:11.164503: Processing video segment 752
# 2024-04-09 19:02:11.969054: Processing video segment 1039
# 2024-04-09 19:02:12.767549: Processing video segment 765
# 2024-04-09 19:02:13.846319: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene27-camera1.mov with video_id 62
# 2024-04-09 19:02:16.131419: Processing video segment 9015
# 2024-04-09 19:02:16.578628: Processing video segment 4304
# 2024-04-09 19:02:17.067791: Processing video segment 9289
# 2024-04-09 19:02:17.646517: Processing video segment 774
# 2024-04-09 19:02:18.561426: Processing video segment 778
# 2024-04-09 19:02:19.197618: Processing video segment 782
# 2024-04-09 19:02:20.185441: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene28-camera1.mov with video_id 63
# 2024-04-09 19:02:21.439119: Processing video segment 786
# 2024-04-09 19:02:21.886971: Processing video segment 5333
# 2024-04-09 19:02:22.379814: Processing video segment 150
# 2024-04-09 19:02:23.010359: Processing video segment 990
# 2024-04-09 19:02:23.693295: Processing video segment 23
# 2024-04-09 19:02:24.336342: Processing video segment 6705
# 2024-04-09 19:02:25.006208: Processing video segment 794
# 2024-04-09 19:02:26.032201: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene29-camera1.mov with video_id 64
# 2024-04-09 19:02:27.256544: Processing video segment 803
# 2024-04-09 19:02:28.031419: Processing video segment 807
# 2024-04-09 19:02:28.760832: Processing video segment 814
# 2024-04-09 19:02:29.616469: Processing video segment 2185
# 2024-04-09 19:02:30.574599: Processing video segment 811
# 2024-04-09 19:02:31.544028: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene3-camera1.mov with video_id 65
# 2024-04-09 19:02:32.782705: Processing video segment 7707
# 2024-04-09 19:02:33.600830: Processing video segment 7901
# 2024-04-09 19:02:34.554765: Processing video segment 3805
# 2024-04-09 19:02:35.560180: Processing video segment 6396
# 2024-04-09 19:02:36.553691: Processing video segment 8459
# 2024-04-09 19:02:37.748741: Processing video segment 8458
# 2024-04-09 19:02:39.084508: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene30-camera1.mov with video_id 66
# 2024-04-09 19:02:39.823493: Processing video segment 6844
# 2024-04-09 19:02:40.427133: Processing video segment 817
# 2024-04-09 19:02:41.009374: Processing video segment 823
# 2024-04-09 19:02:41.824583: Processing video segment 827
# 2024-04-09 19:02:42.591694: Processing video segment 831
# 2024-04-09 19:02:43.470500: Processing video segment 835
# 2024-04-09 19:02:44.774681: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene31-camera1.mov with video_id 67
# 2024-04-09 19:02:45.258086: Processing video segment 7539
# 2024-04-09 19:02:45.821944: Processing video segment 9431
# 2024-04-09 19:02:46.324991: Processing video segment 840
# 2024-04-09 19:02:47.107053: Processing video segment 845
# 2024-04-09 19:02:47.786433: Processing video segment 849
# 2024-04-09 19:02:48.794296: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene32-camera1.mov with video_id 68
# 2024-04-09 19:02:49.301819: Processing video segment 856
# 2024-04-09 19:02:49.717278: Processing video segment 4578
# 2024-04-09 19:02:50.485049: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene33-camera1.mov with video_id 69
# 2024-04-09 19:02:51.043294: Processing video segment 8745
# 2024-04-09 19:02:51.513066: Processing video segment 870
# 2024-04-09 19:02:52.102119: Processing video segment 815
# 2024-04-09 19:02:52.770061: Processing video segment 877
# 2024-04-09 19:02:53.405970: Processing video segment 883
# 2024-04-09 19:02:54.205232: Processing video segment 885
# 2024-04-09 19:02:55.078577: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene34-camera1.mov with video_id 70
# 2024-04-09 19:02:56.354735: Processing video segment 898
# 2024-04-09 19:02:56.943229: Processing video segment 890
# 2024-04-09 19:02:57.738703: Processing video segment 899
# 2024-04-09 19:02:58.508676: Processing video segment 8659
# 2024-04-09 19:02:59.112044: Processing video segment 895
# 2024-04-09 19:03:00.030262: Processing video segment 902
# 2024-04-09 19:03:00.792458: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene35-camera1.mov with video_id 71
# 2024-04-09 19:03:01.559279: Processing video segment 1632
# 2024-04-09 19:03:02.061162: Processing video segment 908
# 2024-04-09 19:03:02.820396: Processing video segment 910
# 2024-04-09 19:03:03.505110: Processing video segment 912
# 2024-04-09 19:03:04.291108: Processing video segment 321
# 2024-04-09 19:03:05.267494: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene36-camera1.mov with video_id 72
# 2024-04-09 19:03:06.545989: Processing video segment 4843
# 2024-04-09 19:03:06.967012: Processing video segment 933
# 2024-04-09 19:03:07.550138: Processing video segment 938
# 2024-04-09 19:03:08.056272: Processing video segment 942
# 2024-04-09 19:03:08.692631: Processing video segment 950
# 2024-04-09 19:03:09.290241: Processing video segment 956
# 2024-04-09 19:03:10.076351: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene37-camera1.mov with video_id 73
# 2024-04-09 19:03:10.981070: Processing video segment 958
# 2024-04-09 19:03:11.677622: Processing video segment 962
# 2024-04-09 19:03:12.301132: Processing video segment 966
# 2024-04-09 19:03:12.925518: Processing video segment 6713
# 2024-04-09 19:03:13.492420: Processing video segment 970
# 2024-04-09 19:03:14.223896: Processing video segment 978
# 2024-04-09 19:03:15.067244: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene38-camera1.mov with video_id 74
# 2024-04-09 19:03:15.749738: Processing video segment 979
# 2024-04-09 19:03:16.434587: Processing video segment 983
# 2024-04-09 19:03:17.066296: Processing video segment 358
# 2024-04-09 19:03:17.737807: Processing video segment 766
# 2024-04-09 19:03:18.380863: Processing video segment 9661
# 2024-04-09 19:03:19.236418: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene39-camera1.mov with video_id 75
# 2024-04-09 19:03:20.144282: Processing video segment 9435
# 2024-04-09 19:03:20.624331: Processing video segment 8516
# 2024-04-09 19:03:21.197909: Processing video segment 9669
# 2024-04-09 19:03:21.734224: Processing video segment 993
# 2024-04-09 19:03:22.537496: Processing video segment 994
# 2024-04-09 19:03:23.313230: Processing video segment 997
# 2024-04-09 19:03:24.208417: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene4-camera1.mov with video_id 76
# 2024-04-09 19:03:26.096306: Processing video segment 7717
# 2024-04-09 19:03:26.848203: Processing video segment 7722
# 2024-04-09 19:03:27.403253: Processing video segment 7914
# 2024-04-09 19:03:28.087340: Processing video segment 7915
# 2024-04-09 19:03:28.923081: Processing video segment 8836
# 2024-04-09 19:03:29.705357: Processing video segment 9341
# 2024-04-09 19:03:30.566934: Processing video segment 6530
# 2024-04-09 19:03:31.624133: Processing video segment 286
# 2024-04-09 19:03:32.550605: Processing video segment 5733
# 2024-04-09 19:03:33.750293: Processing video segment 7
# 2024-04-09 19:03:35.078255: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene40-camera1.mov with video_id 77
# 2024-04-09 19:03:37.386088: Processing video segment 7252
# 2024-04-09 19:03:37.971204: Processing video segment 5589
# 2024-04-09 19:03:38.421156: Processing video segment 1004
# 2024-04-09 19:03:39.052576: Processing video segment 1009
# 2024-04-09 19:03:39.750940: Processing video segment 1012
# 2024-04-09 19:03:40.685582: Processing video segment 6360
# 2024-04-09 19:03:41.483433: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene41-camera1.mov with video_id 78
# 2024-04-09 19:03:42.690801: Processing video segment 1024
# 2024-04-09 19:03:43.121200: Processing video segment 1031
# 2024-04-09 19:03:43.608485: Processing video segment 1035
# 2024-04-09 19:03:44.206312: Processing video segment 1268
# 2024-04-09 19:03:44.910150: Processing video segment 461
# 2024-04-09 19:03:45.623111: Processing video segment 9569
# 2024-04-09 19:03:46.622176: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene42-camera1.mov with video_id 79
# 2024-04-09 19:03:47.514131: Processing video segment 1046
# 2024-04-09 19:03:48.012581: Processing video segment 1051
# 2024-04-09 19:03:48.456848: Processing video segment 1076
# 2024-04-09 19:03:49.273601: Processing video segment 1079
# 2024-04-09 19:03:50.125554: Processing video segment 1081
# 2024-04-09 19:03:51.221730: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene43-camera1.mov with video_id 80
# 2024-04-09 19:03:52.231200: Processing video segment 1085
# 2024-04-09 19:03:52.673824: Processing video segment 674
# 2024-04-09 19:03:53.263248: Processing video segment 3026
# 2024-04-09 19:03:54.031837: Processing video segment 1098
# 2024-04-09 19:03:54.776178: Processing video segment 1102
# 2024-04-09 19:03:55.601072: Processing video segment 1106
# 2024-04-09 19:03:56.522655: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene44-camera1.mov with video_id 81
# 2024-04-09 19:03:57.082033: Processing video segment 1115
# 2024-04-09 19:03:57.534836: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene45-camera1.mov with video_id 82
# 2024-04-09 19:03:58.954779: Processing video segment 1121
# 2024-04-09 19:03:59.593768: Processing video segment 1126
# 2024-04-09 19:04:00.113176: Processing video segment 1138
# 2024-04-09 19:04:00.714822: Processing video segment 1139
# 2024-04-09 19:04:01.471744: Processing video segment 1134
# 2024-04-09 19:04:02.094716: Processing video segment 1146
# 2024-04-09 19:04:02.989402: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene46-camera1.mov with video_id 83
# 2024-04-09 19:04:03.938979: Processing video segment 1151
# 2024-04-09 19:04:04.412950: Processing video segment 266
# 2024-04-09 19:04:04.937837: Processing video segment 174
# 2024-04-09 19:04:05.618465: Processing video segment 1156
# 2024-04-09 19:04:06.208819: Processing video segment 1161
# 2024-04-09 19:04:06.918883: Processing video segment 1302
# 2024-04-09 19:04:07.688705: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene47-camera1.mov with video_id 84
# 2024-04-09 19:04:08.539396: Processing video segment 6746
# 2024-04-09 19:04:09.090258: Processing video segment 1168
# 2024-04-09 19:04:09.577628: Processing video segment 4590
# 2024-04-09 19:04:10.148601: Processing video segment 7273
# 2024-04-09 19:04:10.956473: Processing video segment 1176
# 2024-04-09 19:04:11.699296: Processing video segment 1179
# 2024-04-09 19:04:12.676606: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene48-camera1.mov with video_id 85
# 2024-04-09 19:04:13.320027: Processing video segment 1180
# 2024-04-09 19:04:13.728757: Processing video segment 1183
# 2024-04-09 19:04:14.137822: Processing video segment 1184
# 2024-04-09 19:04:14.782548: Processing video segment 1192
# 2024-04-09 19:04:15.372241: Processing video segment 1198
# 2024-04-09 19:04:16.164798: Processing video segment 7276
# 2024-04-09 19:04:17.132472: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene49-camera1.mov with video_id 86
# 2024-04-09 19:04:17.707032: Processing video segment 1208
# 2024-04-09 19:04:18.166505: Processing video segment 1212
# 2024-04-09 19:04:18.728409: Processing video segment 1216
# 2024-04-09 19:04:19.482343: Processing video segment 7883
# 2024-04-09 19:04:20.283993: Processing video segment 9664
# 2024-04-09 19:04:21.049555: Processing video segment 1220
# 2024-04-09 19:04:22.009340: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene5-camera1.mov with video_id 87
# 2024-04-09 19:04:23.331724: Processing video segment 301
# 2024-04-09 19:04:23.715160: Processing video segment 306
# 2024-04-09 19:04:24.231490: Processing video segment 308
# 2024-04-09 19:04:24.957405: Processing video segment 3372
# 2024-04-09 19:04:25.628462: Processing video segment 311
# 2024-04-09 19:04:26.285587: Processing video segment 328
# 2024-04-09 19:04:27.165599: Processing video segment 334
# 2024-04-09 19:04:28.120441: Processing video segment 336
# 2024-04-09 19:04:29.011747: Processing video segment 338
# 2024-04-09 19:04:30.134633: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene50-camera1.mov with video_id 88
# 2024-04-09 19:04:30.814270: Processing video segment 211
# 2024-04-09 19:04:31.304341: Processing video segment 9666
# 2024-04-09 19:04:31.916291: Processing video segment 1237
# 2024-04-09 19:04:32.493448: Processing video segment 1244
# 2024-04-09 19:04:33.255532: Processing video segment 675
# 2024-04-09 19:04:34.211023: Processing video segment 1247
# 2024-04-09 19:04:35.233614: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene51-camera1.mov with video_id 89
# 2024-04-09 19:04:35.846318: Processing video segment 8295
# 2024-04-09 19:04:36.385483: Processing video segment 1254
# 2024-04-09 19:04:36.946480: Processing video segment 9441
# 2024-04-09 19:04:37.600073: Processing video segment 1263
# 2024-04-09 19:04:38.242723: Processing video segment 9442
# 2024-04-09 19:04:39.022532: Processing video segment 1270
# 2024-04-09 19:04:39.728124: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene52-camera1.mov with video_id 90
# 2024-04-09 19:04:40.669046: Processing video segment 2883
# 2024-04-09 19:04:41.290699: Processing video segment 1282
# 2024-04-09 19:04:41.754549: Processing video segment 1289
# 2024-04-09 19:04:42.383783: Processing video segment 241
# 2024-04-09 19:04:43.073199: Processing video segment 1300
# 2024-04-09 19:04:43.893071: Processing video segment 1297
# 2024-04-09 19:04:44.877619: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene53-camera1.mov with video_id 91
# 2024-04-09 19:04:45.528101: Processing video segment 1306
# 2024-04-09 19:04:45.885382: Processing video segment 1314
# 2024-04-09 19:04:46.596755: Processing video segment 1332
# 2024-04-09 19:04:47.322514: Processing video segment 1341
# 2024-04-09 19:04:48.003064: Processing video segment 1345
# 2024-04-09 19:04:48.920612: Processing video segment 6137
# 2024-04-09 19:04:49.706268: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene54-camera1.mov with video_id 92
# 2024-04-09 19:04:50.328770: Processing video segment 1349
# 2024-04-09 19:04:50.790010: Processing video segment 3957
# 2024-04-09 19:04:51.342834: Processing video segment 1355
# 2024-04-09 19:04:51.875871: Processing video segment 1362
# 2024-04-09 19:04:52.693003: Processing video segment 9670
# 2024-04-09 19:04:53.386551: Processing video segment 1368
# 2024-04-09 19:04:54.275721: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene55-camera1.mov with video_id 93
# 2024-04-09 19:04:55.378217: Processing video segment 7266
# 2024-04-09 19:04:55.799261: Processing video segment 1376
# 2024-04-09 19:04:56.243429: Processing video segment 8366
# 2024-04-09 19:04:56.811492: Processing video segment 1381
# 2024-04-09 19:04:57.454067: Processing video segment 2520
# 2024-04-09 19:04:58.236182: Processing video segment 3074
# 2024-04-09 19:04:58.980213: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene56-camera1.mov with video_id 94
# 2024-04-09 19:04:59.926772: Processing video segment 6067
# 2024-04-09 19:05:00.358493: Processing video segment 1389
# 2024-04-09 19:05:01.006421: Processing video segment 1395
# 2024-04-09 19:05:01.673974: Processing video segment 1400
# 2024-04-09 19:05:02.309342: Processing video segment 1403
# 2024-04-09 19:05:03.013383: Processing video segment 215
# 2024-04-09 19:05:04.002129: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene57-camera1.mov with video_id 95
# 2024-04-09 19:05:04.924403: Processing video segment 1406
# 2024-04-09 19:05:05.576350: Processing video segment 1317
# 2024-04-09 19:05:06.350830: Processing video segment 1421
# 2024-04-09 19:05:06.959636: Processing video segment 1201
# 2024-04-09 19:05:07.947247: Processing video segment 1426
# 2024-04-09 19:05:09.027374: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene58-camera1.mov with video_id 96
# 2024-04-09 19:05:10.113063: Processing video segment 1431
# 2024-04-09 19:05:11.007178: Processing video segment 1438
# 2024-04-09 19:05:11.978414: Processing video segment 1446
# 2024-04-09 19:05:13.034204: Processing video segment 9451
# 2024-04-09 19:05:14.395438: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene59-camera1.mov with video_id 97
# 2024-04-09 19:05:14.986859: Processing video segment 263
# 2024-04-09 19:05:15.369785: Processing video segment 1449
# 2024-04-09 19:05:15.818161: Processing video segment 3763
# 2024-04-09 19:05:16.406351: Processing video segment 1452
# 2024-04-09 19:05:17.120204: Processing video segment 29
# 2024-04-09 19:05:17.929061: Processing video segment 1459
# 2024-04-09 19:05:18.715423: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene6-camera1.mov with video_id 98
# 2024-04-09 19:05:21.848851: Processing video segment 2237
# 2024-04-09 19:05:22.476044: Processing video segment 1125
# 2024-04-09 19:05:23.147681: Processing video segment 6617
# 2024-04-09 19:05:23.928329: Processing video segment 346
# 2024-04-09 19:05:25.030760: Processing video segment 354
# 2024-04-09 19:05:26.163845: Processing video segment 351
# 2024-04-09 19:05:27.352015: Processing video segment 364
# 2024-04-09 19:05:28.491801: Processing video segment 365
# 2024-04-09 19:05:29.727617: Processing video segment 370
# 2024-04-09 19:05:30.967582: Processing video segment 3259
# 2024-04-09 19:05:32.322243: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene60-camera1.mov with video_id 99
# 2024-04-09 19:05:34.083555: Processing video segment 1457
# 2024-04-09 19:05:34.610731: Processing video segment 1467
# 2024-04-09 19:05:35.137105: Processing video segment 1471
# 2024-04-09 19:05:35.833158: Processing video segment 1476
# 2024-04-09 19:05:36.511361: Processing video segment 1480
# 2024-04-09 19:05:37.443862: Processing video segment 1486
# 2024-04-09 19:05:38.225686: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene61-camera1.mov with video_id 100
# 2024-04-09 19:05:39.442361: Processing video segment 1495
# 2024-04-09 19:05:39.807678: Processing video segment 37
# 2024-04-09 19:05:40.371956: Processing video segment 41
# 2024-04-09 19:05:40.945268: Processing video segment 1500
# 2024-04-09 19:05:41.585740: Processing video segment 1504
# 2024-04-09 19:05:42.553478: Processing video segment 1513
# 2024-04-09 19:05:43.330623: Processing video segment 7771
# 2024-04-09 19:05:44.112949: Processing video segment 1521
# 2024-04-09 19:05:45.039809: Processing video segment 4343
# 2024-04-09 19:05:45.982138: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene62-camera1.mov with video_id 101
# 2024-04-09 19:05:46.772961: Processing video segment 1529
# 2024-04-09 19:05:47.362596: Processing video segment 1534
# 2024-04-09 19:05:47.904363: Processing video segment 1542
# 2024-04-09 19:05:48.515413: Processing video segment 1553
# 2024-04-09 19:05:49.338440: Processing video segment 1561
# 2024-04-09 19:05:50.083669: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene63-camera1.mov with video_id 102
# 2024-04-09 19:05:50.950785: Processing video segment 9674
# 2024-04-09 19:05:51.468445: Processing video segment 1579
# 2024-04-09 19:05:51.942198: Processing video segment 2416
# 2024-04-09 19:05:52.780257: Processing video segment 2402
# 2024-04-09 19:05:53.413208: Processing video segment 1584
# 2024-04-09 19:05:54.129694: Processing video segment 1592
# 2024-04-09 19:05:55.182352: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene64-camera1.mov with video_id 103
# 2024-04-09 19:05:57.505761: Processing video segment 6640
# 2024-04-09 19:05:58.254477: Processing video segment 6641
# 2024-04-09 19:05:59.120831: Processing video segment 1598
# 2024-04-09 19:05:59.645575: Processing video segment 1603
# 2024-04-09 19:06:00.193170: Processing video segment 4388
# 2024-04-09 19:06:00.903718: Processing video segment 1255
# 2024-04-09 19:06:01.764528: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene65-camera1.mov with video_id 104
# 2024-04-09 19:06:03.201487: Processing video segment 6300
# 2024-04-09 19:06:03.663380: Processing video segment 1618
# 2024-04-09 19:06:04.459393: Processing video segment 1611
# 2024-04-09 19:06:05.220366: Processing video segment 1641
# 2024-04-09 19:06:05.929406: Processing video segment 1644
# 2024-04-09 19:06:06.764737: Processing video segment 1648
# 2024-04-09 19:06:07.619438: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene66-camera1.mov with video_id 105
# 2024-04-09 19:06:08.336219: Processing video segment 1651
# 2024-04-09 19:06:08.928276: Processing video segment 3742
# 2024-04-09 19:06:09.449153: Processing video segment 1664
# 2024-04-09 19:06:10.100323: Processing video segment 1676
# 2024-04-09 19:06:10.675020: Processing video segment 1672
# 2024-04-09 19:06:11.473947: Processing video segment 1680
# 2024-04-09 19:06:12.451498: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene67-camera1.mov with video_id 106
# 2024-04-09 19:06:14.719885: Processing video segment 1684
# 2024-04-09 19:06:15.308203: Processing video segment 1688
# 2024-04-09 19:06:15.859162: Processing video segment 1692
# 2024-04-09 19:06:16.511823: Processing video segment 1698
# 2024-04-09 19:06:17.379854: Processing video segment 1718
# 2024-04-09 19:06:18.101968: Processing video segment 6110
# 2024-04-09 19:06:18.937442: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene68-camera1.mov with video_id 107
# 2024-04-09 19:06:20.116022: Processing video segment 9454
# 2024-04-09 19:06:20.813944: Processing video segment 1723
# 2024-04-09 19:06:21.589152: Processing video segment 1733
# 2024-04-09 19:06:22.292813: Processing video segment 1728
# 2024-04-09 19:06:22.996622: Processing video segment 1736
# 2024-04-09 19:06:23.881075: Processing video segment 7894
# 2024-04-09 19:06:24.828171: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene69-camera1.mov with video_id 108
# 2024-04-09 19:06:25.956425: Processing video segment 1741
# 2024-04-09 19:06:26.534805: Processing video segment 1744
# 2024-04-09 19:06:27.028867: Processing video segment 6954
# 2024-04-09 19:06:27.477907: Processing video segment 1749
# 2024-04-09 19:06:28.101381: Processing video segment 1752
# 2024-04-09 19:06:28.867587: Processing video segment 1755
# 2024-04-09 19:06:29.752314: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene7-camera1.mov with video_id 109
# 2024-04-09 19:06:31.278873: Processing video segment 373
# 2024-04-09 19:06:31.827248: Processing video segment 8389
# 2024-04-09 19:06:32.455482: Processing video segment 389
# 2024-04-09 19:06:33.487908: Processing video segment 395
# 2024-04-09 19:06:34.308008: Processing video segment 399
# 2024-04-09 19:06:35.324510: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene70-camera1.mov with video_id 110
# 2024-04-09 19:06:36.127904: Processing video segment 1759
# 2024-04-09 19:06:36.863663: Processing video segment 1762
# 2024-04-09 19:06:37.504602: Processing video segment 1764
# 2024-04-09 19:06:38.329101: Processing video segment 1767
# 2024-04-09 19:06:39.275151: Processing video segment 7049
# 2024-04-09 19:06:40.204993: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene71-camera1.mov with video_id 111
# 2024-04-09 19:06:40.775150: Processing video segment 9455
# 2024-04-09 19:06:41.254919: Processing video segment 1771
# 2024-04-09 19:06:41.991580: Processing video segment 1781
# 2024-04-09 19:06:42.733031: Processing video segment 1788
# 2024-04-09 19:06:43.365326: Processing video segment 1794
# 2024-04-09 19:06:44.162931: Processing video segment 270
# 2024-04-09 19:06:44.970929: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene72-camera1.mov with video_id 112
# 2024-04-09 19:06:46.020187: Processing video segment 272
# 2024-04-09 19:06:46.635609: Processing video segment 1800
# 2024-04-09 19:06:47.115957: Processing video segment 6672
# 2024-04-09 19:06:47.705688: Processing video segment 1808
# 2024-04-09 19:06:48.537609: Processing video segment 1803
# 2024-04-09 19:06:49.349955: Processing video segment 1805
# 2024-04-09 19:06:50.314637: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene73-camera1.mov with video_id 113
# 2024-04-09 19:06:51.158532: Processing video segment 7943
# 2024-04-09 19:06:51.712926: Processing video segment 1810
# 2024-04-09 19:06:52.248488: Processing video segment 2155
# 2024-04-09 19:06:52.883160: Processing video segment 1819
# 2024-04-09 19:06:53.624651: Processing video segment 1019
# 2024-04-09 19:06:54.340247: Processing video segment 1831
# 2024-04-09 19:06:55.221941: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene74-camera1.mov with video_id 114
# 2024-04-09 19:06:56.005843: Processing video segment 1835
# 2024-04-09 19:06:56.703366: Processing video segment 4541
# 2024-04-09 19:06:57.300604: Processing video segment 9460
# 2024-04-09 19:06:57.896561: Processing video segment 1839
# 2024-04-09 19:06:58.656752: Processing video segment 1836
# 2024-04-09 19:06:59.401846: Processing video segment 9677
# 2024-04-09 19:07:00.229424: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene75-camera1.mov with video_id 115
# 2024-04-09 19:07:01.080504: Processing video segment 1845
# 2024-04-09 19:07:01.567848: Processing video segment 9679
# 2024-04-09 19:07:02.257815: Processing video segment 9464
# 2024-04-09 19:07:02.875332: Processing video segment 1849
# 2024-04-09 19:07:03.702378: Processing video segment 6589
# 2024-04-09 19:07:04.558296: Processing video segment 6590
# 2024-04-09 19:07:05.477987: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene76-camera1.mov with video_id 116
# 2024-04-09 19:07:06.025582: Processing video segment 1852
# 2024-04-09 19:07:06.454011: Processing video segment 1855
# 2024-04-09 19:07:06.937155: Processing video segment 6820
# 2024-04-09 19:07:07.451496: Processing video segment 9566
# 2024-04-09 19:07:08.280086: Processing video segment 1867
# 2024-04-09 19:07:08.923058: Processing video segment 4228
# 2024-04-09 19:07:09.717923: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene77-camera1.mov with video_id 117
# 2024-04-09 19:07:10.393592: Processing video segment 1870
# 2024-04-09 19:07:10.832465: Processing video segment 1880
# 2024-04-09 19:07:11.417808: Processing video segment 1875
# 2024-04-09 19:07:12.140428: Processing video segment 1883
# 2024-04-09 19:07:12.891371: Processing video segment 1886
# 2024-04-09 19:07:13.660101: Processing video segment 1939
# 2024-04-09 19:07:14.481298: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene78-camera1.mov with video_id 118
# 2024-04-09 19:07:15.277352: Processing video segment 619
# 2024-04-09 19:07:15.819371: Processing video segment 1905
# 2024-04-09 19:07:16.557287: Processing video segment 6369
# 2024-04-09 19:07:17.167414: Processing video segment 6374
# 2024-04-09 19:07:17.919009: Processing video segment 1912
# 2024-04-09 19:07:18.624248: Processing video segment 8767
# 2024-04-09 19:07:19.566956: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene79-camera1.mov with video_id 119
# 2024-04-09 19:07:20.492038: Processing video segment 1920
# 2024-04-09 19:07:21.104443: Processing video segment 1921
# 2024-04-09 19:07:21.801900: Processing video segment 8626
# 2024-04-09 19:07:22.841443: Processing video segment 1929
# 2024-04-09 19:07:23.919409: Processing video segment 1935
# 2024-04-09 19:07:24.951324: Processing video segment 1927
# 2024-04-09 19:07:26.155951: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene8-camera1.mov with video_id 120
# 2024-04-09 19:07:26.982162: Processing video segment 406
# 2024-04-09 19:07:27.636628: Processing video segment 418
# 2024-04-09 19:07:28.312195: Processing video segment 9393
# 2024-04-09 19:07:29.222955: Processing video segment 9396
# 2024-04-09 19:07:30.700271: Processing video segment 9398
# 2024-04-09 19:07:32.275215: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene81-camera1.mov with video_id 121
# 2024-04-09 19:07:32.929714: Processing video segment 1925
# 2024-04-09 19:07:33.646797: Processing video segment 7842
# 2024-04-09 19:07:34.264557: Processing video segment 2869
# 2024-04-09 19:07:35.216797: Processing video segment 1942
# 2024-04-09 19:07:36.045233: Processing video segment 1948
# 2024-04-09 19:07:37.069560: Processing video segment 2893
# 2024-04-09 19:07:38.147148: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene82-camera1.mov with video_id 122
# 2024-04-09 19:07:39.055270: Processing video segment 1955
# 2024-04-09 19:07:39.612298: Processing video segment 1961
# 2024-04-09 19:07:40.433799: Processing video segment 1963
# 2024-04-09 19:07:41.096330: Processing video segment 9467
# 2024-04-09 19:07:41.909782: Processing video segment 4713
# 2024-04-09 19:07:42.805079: Processing video segment 1971
# 2024-04-09 19:07:43.852404: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene83-camera1.mov with video_id 123
# 2024-04-09 19:07:44.990743: Processing video segment 1382
# 2024-04-09 19:07:45.445114: Processing video segment 1981
# 2024-04-09 19:07:45.905847: Processing video segment 1994
# 2024-04-09 19:07:46.700354: Processing video segment 1991
# 2024-04-09 19:07:47.415765: Processing video segment 2003
# 2024-04-09 19:07:48.086948: Processing video segment 9470
# 2024-04-09 19:07:49.062897: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene84-camera1.mov with video_id 124
# 2024-04-09 19:07:52.029186: Processing video segment 9474
# 2024-04-09 19:07:52.600251: Processing video segment 9476
# 2024-04-09 19:07:53.112837: Processing video segment 2007
# 2024-04-09 19:07:53.897775: Processing video segment 2011
# 2024-04-09 19:07:54.707600: Processing video segment 2026
# 2024-04-09 19:07:55.597631: Processing video segment 2021
# 2024-04-09 19:07:56.321717: Processing video segment 2014
# 2024-04-09 19:07:57.150523: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_11/scene9-camera1.mov with video_id 125
# 2024-04-09 19:07:58.726928: Processing video segment 6618
# 2024-04-09 19:07:59.372721: Processing video segment 495
# 2024-04-09 19:07:59.877975: Processing video segment 431
# 2024-04-09 19:08:00.484722: Processing video segment 435
# 2024-04-09 19:08:01.404746: Processing video segment 6514
# 2024-04-09 19:08:02.295261: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene1-camera1.mov with video_id 126
# 2024-04-09 19:08:03.330321: Processing video segment 2018
# 2024-04-09 19:08:03.856380: Processing video segment 2029
# 2024-04-09 19:08:04.771279: Processing video segment 2034
# 2024-04-09 19:08:05.369517: Processing video segment 2042
# 2024-04-09 19:08:06.265926: Processing video segment 2048
# 2024-04-09 19:08:07.141099: Processing video segment 1888
# 2024-04-09 19:08:07.990090: Processing video segment 2049
# 2024-04-09 19:08:09.122838: Processing video segment 1775
# 2024-04-09 19:08:10.327008: Processing video segment 2054
# 2024-04-09 19:08:11.599259: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene10-camera1.mov with video_id 127
# 2024-04-09 19:08:12.344895: Processing video segment 9683
# 2024-04-09 19:08:12.804083: Processing video segment 2355
# 2024-04-09 19:08:13.342186: Processing video segment 1508
# 2024-04-09 19:08:14.074682: Processing video segment 6062
# 2024-04-09 19:08:14.768653: Processing video segment 2361
# 2024-04-09 19:08:15.469133: Processing video segment 2365
# 2024-04-09 19:08:16.452048: Processing video segment 2369
# 2024-04-09 19:08:17.449428: Processing video segment 8335
# 2024-04-09 19:08:18.446515: Processing video segment 2376
# 2024-04-09 19:08:19.773518: Processing video segment 2380
# 2024-04-09 19:08:21.238347: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene11-camera1.mov with video_id 128
# 2024-04-09 19:08:24.736098: Processing video segment 2384
# 2024-04-09 19:08:25.375459: Processing video segment 6211
# 2024-04-09 19:08:25.987143: Processing video segment 2390
# 2024-04-09 19:08:26.433840: Processing video segment 2403
# 2024-04-09 19:08:27.204176: Processing video segment 2419
# 2024-04-09 19:08:28.071567: Processing video segment 2423
# 2024-04-09 19:08:28.729938: Processing video segment 9480
# 2024-04-09 19:08:29.672543: Processing video segment 2430
# 2024-04-09 19:08:30.699128: Processing video segment 2434
# 2024-04-09 19:08:31.899533: Processing video segment 3421
# 2024-04-09 19:08:32.986274: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene12-camera1.mov with video_id 129
# 2024-04-09 19:08:34.475594: Processing video segment 2440
# 2024-04-09 19:08:35.070285: Processing video segment 2446
# 2024-04-09 19:08:35.657773: Processing video segment 2451
# 2024-04-09 19:08:36.285817: Processing video segment 2455
# 2024-04-09 19:08:37.205313: Processing video segment 2458
# 2024-04-09 19:08:38.095774: Processing video segment 2470
# 2024-04-09 19:08:38.862220: Processing video segment 4244
# 2024-04-09 19:08:39.786601: Processing video segment 2472
# 2024-04-09 19:08:40.744340: Processing video segment 2502
# 2024-04-09 19:08:41.700329: Processing video segment 4730
# 2024-04-09 19:08:42.950884: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene13-camera1.mov with video_id 130
# 2024-04-09 19:08:43.831902: Processing video segment 2724
# 2024-04-09 19:08:44.370565: Processing video segment 2371
# 2024-04-09 19:08:44.879515: Processing video segment 2514
# 2024-04-09 19:08:45.531644: Processing video segment 8504
# 2024-04-09 19:08:46.389167: Processing video segment 2515
# 2024-04-09 19:08:47.068149: Processing video segment 2522
# 2024-04-09 19:08:48.084210: Processing video segment 2536
# 2024-04-09 19:08:49.023787: Processing video segment 2539
# 2024-04-09 19:08:50.108693: Processing video segment 2542
# 2024-04-09 19:08:51.127552: Processing video segment 3831
# 2024-04-09 19:08:52.220177: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene14-camera1.mov with video_id 131
# 2024-04-09 19:08:52.993393: Processing video segment 2549
# 2024-04-09 19:08:53.423182: Processing video segment 2561
# 2024-04-09 19:08:53.875011: Processing video segment 7347
# 2024-04-09 19:08:54.409195: Processing video segment 2563
# 2024-04-09 19:08:55.154200: Processing video segment 7826
# 2024-04-09 19:08:55.942924: Processing video segment 9686
# 2024-04-09 19:08:56.847697: Processing video segment 8673
# 2024-04-09 19:08:57.743316: Processing video segment 2569
# 2024-04-09 19:08:58.597902: Processing video segment 2572
# 2024-04-09 19:08:59.509304: Processing video segment 2575
# 2024-04-09 19:09:00.594447: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene15-camera1.mov with video_id 132
# 2024-04-09 19:09:01.237150: Processing video segment 2577
# 2024-04-09 19:09:01.731976: Processing video segment 2584
# 2024-04-09 19:09:02.234839: Processing video segment 2595
# 2024-04-09 19:09:02.792413: Processing video segment 2588
# 2024-04-09 19:09:03.429475: Processing video segment 2963
# 2024-04-09 19:09:04.441271: Processing video segment 678
# 2024-04-09 19:09:05.173361: Processing video segment 2459
# 2024-04-09 19:09:06.087444: Processing video segment 2604
# 2024-04-09 19:09:07.227894: Processing video segment 9063
# 2024-04-09 19:09:08.546302: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene16-camera1.mov with video_id 133
# 2024-04-09 19:09:09.365926: Processing video segment 4413
# 2024-04-09 19:09:10.069362: Processing video segment 2606
# 2024-04-09 19:09:10.809044: Processing video segment 9485
# 2024-04-09 19:09:11.493915: Processing video segment 2609
# 2024-04-09 19:09:12.126311: Processing video segment 2614
# 2024-04-09 19:09:12.893449: Processing video segment 2628
# 2024-04-09 19:09:13.806251: Processing video segment 6810
# 2024-04-09 19:09:15.249450: Processing video segment 2634
# 2024-04-09 19:09:16.646127: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2008_01_18/scene17-camera1.mov with video_id 134
# 2024-04-09 19:09:19.647490: Processing video segment 5974
# 2024-04-09 19:09:20.367792: Processing video segment 2640
# ...
# 2024-04-09 19:53:03.197063: Processing video segment 4927
# 2024-04-09 19:53:04.432866: Processing video segment 5448
# 2024-04-09 19:53:05.697126: Processing video segment 5450
# 2024-04-09 19:53:07.037301: Processing video segment 5487
# 2024-04-09 19:53:08.341547: Processing video segment 5489
# 2024-04-09 19:53:09.800768: Processing video segment 5961
# 2024-04-09 19:53:11.436315: Processing video segment 5965
# 2024-04-09 19:53:13.000888: Processing video segment 6578
# 2024-04-09 19:53:14.517972: Processing video segment 6580
# 2024-04-09 19:53:16.068243: Processing video segment 6991
# 2024-04-09 19:53:17.851366: Processing video segment 6993
# 2024-04-09 19:53:19.730431: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene20-camera1.mov with video_id 700
# 2024-04-09 19:53:20.311410: Processing video segment 6295
# 2024-04-09 19:53:20.838336: Processing video segment 69
# 2024-04-09 19:53:21.366549: Processing video segment 5259
# 2024-04-09 19:53:22.108374: Processing video segment 4685
# 2024-04-09 19:53:22.775537: Processing video segment 5825
# 2024-04-09 19:53:23.650493: Processing video segment 4850
# 2024-04-09 19:53:24.385301: Processing video segment 4881
# 2024-04-09 19:53:25.276797: Processing video segment 6700
# 2024-04-09 19:53:26.161487: Processing video segment 7526
# 2024-04-09 19:53:27.300949: Processing video segment 5356
# 2024-04-09 19:53:28.464037: Processing video segment 5692
# 2024-04-09 19:53:29.723198: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene21-camera1.mov with video_id 701
# 2024-04-09 19:53:30.559030: Processing video segment 9572
# 2024-04-09 19:53:31.051611: Processing video segment 9579
# 2024-04-09 19:53:31.722865: Processing video segment 9525
# 2024-04-09 19:53:32.299214: Processing video segment 9586
# 2024-04-09 19:53:32.986012: Processing video segment 6437
# 2024-04-09 19:53:33.832267: Processing video segment 226
# 2024-04-09 19:53:34.790102: Processing video segment 90
# 2024-04-09 19:53:35.609063: Processing video segment 6682
# 2024-04-09 19:53:36.525151: Processing video segment 6676
# 2024-04-09 19:53:37.713559: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene22-camera1.mov with video_id 702
# 2024-04-09 19:53:38.274025: Processing video segment 9558
# 2024-04-09 19:53:38.858517: Processing video segment 6774
# 2024-04-09 19:53:39.467777: Processing video segment 6832
# 2024-04-09 19:53:40.314043: Processing video segment 6858
# 2024-04-09 19:53:41.010780: Processing video segment 6964
# 2024-04-09 19:53:41.749408: Processing video segment 8005
# 2024-04-09 19:53:42.515274: Processing video segment 7621
# 2024-04-09 19:53:43.273078: Processing video segment 7106
# 2024-04-09 19:53:44.161276: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene23-camera1.mov with video_id 703
# 2024-04-09 19:53:45.272939: Processing video segment 3558
# 2024-04-09 19:53:45.807140: Processing video segment 322
# 2024-04-09 19:53:46.486164: Processing video segment 5102
# 2024-04-09 19:53:47.288770: Processing video segment 3360
# 2024-04-09 19:53:48.043739: Processing video segment 387
# 2024-04-09 19:53:48.851143: Processing video segment 715
# 2024-04-09 19:53:49.666779: Processing video segment 1699
# 2024-04-09 19:53:50.560422: Processing video segment 3350
# 2024-04-09 19:53:51.535382: Processing video segment 611
# 2024-04-09 19:53:52.488642: Processing video segment 6258
# 2024-04-09 19:53:53.382725: Processing video segment 719
# 2024-04-09 19:53:54.557908: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene24-camera1.mov with video_id 704
# 2024-04-09 19:53:55.377857: Processing video segment 3705
# 2024-04-09 19:53:55.936430: Processing video segment 4848
# 2024-04-09 19:53:56.452426: Processing video segment 756
# 2024-04-09 19:53:57.187447: Processing video segment 8395
# 2024-04-09 19:53:57.976740: Processing video segment 3053
# 2024-04-09 19:53:58.702104: Processing video segment 27
# 2024-04-09 19:53:59.487018: Processing video segment 903
# 2024-04-09 19:54:00.501504: Processing video segment 936
# 2024-04-09 19:54:01.467935: Processing video segment 3623
# 2024-04-09 19:54:02.324378: Processing video segment 2228
# 2024-04-09 19:54:03.352390: Processing video segment 3339
# 2024-04-09 19:54:04.478828: Processing video segment 1112
# 2024-04-09 19:54:05.609489: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene25-camera1.mov with video_id 705
# 2024-04-09 19:54:06.888961: Processing video segment 8205
# 2024-04-09 19:54:07.478428: Processing video segment 6178
# 2024-04-09 19:54:08.163013: Processing video segment 8200
# 2024-04-09 19:54:08.795028: Processing video segment 1206
# 2024-04-09 19:54:09.550422: Processing video segment 9453
# 2024-04-09 19:54:10.366324: Processing video segment 1510
# 2024-04-09 19:54:11.235632: Processing video segment 1519
# 2024-04-09 19:54:12.199942: Processing video segment 1524
# 2024-04-09 19:54:13.146800: Processing video segment 1541
# 2024-04-09 19:54:14.279092: Processing video segment 1573
# 2024-04-09 19:54:15.423968: Processing video segment 1634
# 2024-04-09 19:54:16.490578: Processing video segment 9047
# 2024-04-09 19:54:17.767657: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene26-camera1.mov with video_id 706
# 2024-04-09 19:54:19.344826: Processing video segment 1827
# 2024-04-09 19:54:20.091263: Processing video segment 1090
# 2024-04-09 19:54:20.646668: Processing video segment 1092
# 2024-04-09 19:54:21.401442: Processing video segment 1897
# 2024-04-09 19:54:22.288554: Processing video segment 2073
# 2024-04-09 19:54:23.119075: Processing video segment 621
# 2024-04-09 19:54:23.858394: Processing video segment 2090
# 2024-04-09 19:54:24.889121: Processing video segment 6057
# 2024-04-09 19:54:25.871957: Processing video segment 7785
# 2024-04-09 19:54:26.861413: Processing video segment 7865
# 2024-04-09 19:54:27.933963: Processing video segment 2040
# 2024-04-09 19:54:29.032140: Processing video segment 2169
# 2024-04-09 19:54:30.207857: Processing video segment 6328
# 2024-04-09 19:54:31.337555: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene27-camera1.mov with video_id 707
# 2024-04-09 19:54:32.187764: Processing video segment 6452
# 2024-04-09 19:54:32.718775: Processing video segment 2388
# 2024-04-09 19:54:33.365115: Processing video segment 1985
# 2024-04-09 19:54:34.001881: Processing video segment 4125
# 2024-04-09 19:54:34.678922: Processing video segment 7283
# 2024-04-09 19:54:35.348318: Processing video segment 5671
# 2024-04-09 19:54:36.113350: Processing video segment 3440
# 2024-04-09 19:54:36.911049: Processing video segment 5906
# 2024-04-09 19:54:37.807068: Processing video segment 3496
# 2024-04-09 19:54:38.733921: Processing video segment 3500
# 2024-04-09 19:54:39.770334: Processing video segment 8507
# 2024-04-09 19:54:40.822500: Processing video segment 5412
# 2024-04-09 19:54:41.909565: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene28-camera1.mov with video_id 708
# 2024-04-09 19:54:45.154981: Processing video segment 3556
# 2024-04-09 19:54:46.073862: Processing video segment 3592
# 2024-04-09 19:54:46.909310: Processing video segment 3599
# 2024-04-09 19:54:47.796480: Processing video segment 3650
# 2024-04-09 19:54:48.880921: Processing video segment 6259
# 2024-04-09 19:54:49.710657: Processing video segment 2313
# 2024-04-09 19:54:50.697816: Processing video segment 8932
# 2024-04-09 19:54:51.943444: Processing video segment 3891
# 2024-04-09 19:54:53.136099: Processing video segment 4007
# 2024-04-09 19:54:54.434328: Processing video segment 8743
# 2024-04-09 19:54:55.935934: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene29-camera1.mov with video_id 709
# 2024-04-09 19:54:57.574494: Processing video segment 8196
# 2024-04-09 19:54:58.237304: Processing video segment 1498
# 2024-04-09 19:54:58.800988: Processing video segment 7562
# 2024-04-09 19:54:59.466490: Processing video segment 4465
# 2024-04-09 19:55:00.195287: Processing video segment 8334
# 2024-04-09 19:55:01.011236: Processing video segment 4555
# 2024-04-09 19:55:01.957124: Processing video segment 6559
# 2024-04-09 19:55:03.130353: Processing video segment 1702
# 2024-04-09 19:55:04.367814: Processing video segment 4810
# 2024-04-09 19:55:05.693692: Processing video segment 8919
# 2024-04-09 19:55:07.021071: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene3-camera1.mov with video_id 710
# 2024-04-09 19:55:08.337806: Processing video segment 207
# 2024-04-09 19:55:09.117808: Processing video segment 208
# 2024-04-09 19:55:09.983702: Processing video segment 7416
# 2024-04-09 19:55:10.877467: Processing video segment 7418
# 2024-04-09 19:55:11.974468: Processing video segment 1291
# 2024-04-09 19:55:13.028426: Processing video segment 1293
# 2024-04-09 19:55:14.255373: Processing video segment 7451
# 2024-04-09 19:55:15.326426: Processing video segment 7453
# 2024-04-09 19:55:16.575791: Processing video segment 7683
# 2024-04-09 19:55:17.829154: Processing video segment 7687
# 2024-04-09 19:55:19.151942: Processing video segment 4246
# 2024-04-09 19:55:20.563566: Processing video segment 4247
# 2024-04-09 19:55:21.962204: Processing video segment 4249
# 2024-04-09 19:55:23.446687: Processing video segment 4250
# 2024-04-09 19:55:24.880353: Processing video segment 7754
# 2024-04-09 19:55:26.487807: Processing video segment 7757
# 2024-04-09 19:55:28.169391: Processing video segment 8191
# 2024-04-09 19:55:29.790788: Processing video segment 8193
# 2024-04-09 19:55:31.645662: Processing video segment 8759
# 2024-04-09 19:55:33.698755: Processing video segment 8763
# 2024-04-09 19:55:35.682183: Processing video segment 8785
# 2024-04-09 19:55:37.540481: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene30-camera1.mov with video_id 711
# 2024-04-09 19:55:39.070206: Processing video segment 4409
# 2024-04-09 19:55:39.710469: Processing video segment 4104
# 2024-04-09 19:55:40.411160: Processing video segment 7874
# 2024-04-09 19:55:41.426758: Processing video segment 9360
# 2024-04-09 19:55:42.697048: Processing video segment 5034
# 2024-04-09 19:55:43.765986: Processing video segment 4846
# 2024-04-09 19:55:44.885851: Processing video segment 5169
# 2024-04-09 19:55:46.089881: Processing video segment 5154
# 2024-04-09 19:55:47.448453: Processing video segment 5160
# 2024-04-09 19:55:48.795579: Processing video segment 5279
# 2024-04-09 19:55:50.089795: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene31-camera1.mov with video_id 712
# 2024-04-09 19:55:50.502329: Processing video segment 5428
# 2024-04-09 19:55:51.238837: Processing video segment 5437
# 2024-04-09 19:55:51.945451: Processing video segment 84
# 2024-04-09 19:55:52.478543: Processing video segment 5438
# 2024-04-09 19:55:53.300651: Processing video segment 7768
# 2024-04-09 19:55:54.155339: Processing video segment 5512
# 2024-04-09 19:55:55.051400: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene4-camera1.mov with video_id 713
# 2024-04-09 19:55:55.623580: Processing video segment 8187
# 2024-04-09 19:55:56.461594: Processing video segment 9235
# 2024-04-09 19:55:57.141991: Processing video segment 9241
# 2024-04-09 19:55:58.054689: Processing video segment 9251
# 2024-04-09 19:55:58.954367: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene5-camera1.mov with video_id 714
# 2024-04-09 19:55:59.695303: Processing video segment 2102
# 2024-04-09 19:56:00.391361: Processing video segment 303
# 2024-04-09 19:56:01.177150: Processing video segment 6298
# 2024-04-09 19:56:01.784930: Processing video segment 5033
# 2024-04-09 19:56:02.596630: Processing video segment 304
# 2024-04-09 19:56:03.493953: Processing video segment 4356
# 2024-04-09 19:56:04.324177: Processing video segment 340
# 2024-04-09 19:56:05.318979: Processing video segment 318
# 2024-04-09 19:56:06.526189: Processing video segment 368
# 2024-04-09 19:56:07.459570: Processing video segment 8436
# 2024-04-09 19:56:08.526202: Processing video segment 383
# 2024-04-09 19:56:09.675607: Processing video segment 5572
# 2024-04-09 19:56:10.885669: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene6-camera1.mov with video_id 715
# 2024-04-09 19:56:12.026570: Processing video segment 5720
# 2024-04-09 19:56:12.841072: Processing video segment 6419
# 2024-04-09 19:56:13.653982: Processing video segment 8250
# 2024-04-09 19:56:14.416809: Processing video segment 8310
# 2024-04-09 19:56:15.330724: Processing video segment 547
# 2024-04-09 19:56:16.245690: Processing video segment 4902
# 2024-04-09 19:56:17.367318: Processing video segment 1572
# 2024-04-09 19:56:18.420071: Processing video segment 3626
# 2024-04-09 19:56:19.649206: Processing video segment 5894
# 2024-04-09 19:56:20.956192: Processing video segment 731
# 2024-04-09 19:56:22.195230: Processing video segment 935
# 2024-04-09 19:56:23.420404: Processing video segment 8638
# 2024-04-09 19:56:24.649203: Processing video segment 1066
# 2024-04-09 19:56:26.133795: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene7-camera1.mov with video_id 716
# 2024-04-09 19:56:27.707558: Processing video segment 1276
# 2024-04-09 19:56:28.587962: Processing video segment 3049
# 2024-04-09 19:56:29.576455: Processing video segment 2743
# 2024-04-09 19:56:30.697566: Processing video segment 1043
# 2024-04-09 19:56:31.828771: Processing video segment 6897
# 2024-04-09 19:56:33.006885: Processing video segment 6824
# 2024-04-09 19:56:34.160831: Processing video segment 6871
# 2024-04-09 19:56:35.512855: Processing video segment 7155
# 2024-04-09 19:56:36.789357: Processing video segment 1976
# 2024-04-09 19:56:38.201087: Processing video segment 7362
# 2024-04-09 19:56:39.594911: Processing video segment 8012
# 2024-04-09 19:56:41.001037: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene8-camera1.mov with video_id 717
# 2024-04-09 19:56:42.754554: Processing video segment 1953
# 2024-04-09 19:56:43.519494: Processing video segment 171
# 2024-04-09 19:56:44.523361: Processing video segment 466
# 2024-04-09 19:56:45.404816: Processing video segment 476
# 2024-04-09 19:56:46.511086: Processing video segment 487
# 2024-04-09 19:56:47.556026: Processing video segment 4867
# 2024-04-09 19:56:48.607786: Processing video segment 160
# 2024-04-09 19:56:49.842831: Processing video segment 5753
# 2024-04-09 19:56:51.045797: Processing video segment 727
# 2024-04-09 19:56:52.339691: Processing video segment 798
# 2024-04-09 19:56:53.651831: Processing video segment 2182
# 2024-04-09 19:56:55.236917: Downloading http://csr.bu.edu/ftp/asl/asllvd/asl-data2/quicktime/ASL_2010_08_10_Liz_additional_lexicon_signs/scene9-camera1.mov with video_id 718
# 2024-04-09 19:56:56.098862: Processing video segment 261
# 2024-04-09 19:56:56.841516: Processing video segment 5506
# 2024-04-09 19:56:57.573306: Processing video segment 1166
# 2024-04-09 19:56:58.317398: Processing video segment 1020
# 2024-04-09 19:56:58.833818: Processing video segment 7435
# 2024-04-09 19:56:59.826613: Processing video segment 33
# 2024-04-09 19:57:00.601022: Processing video segment 1682
# 2024-04-09 19:57:01.620160: Processing video segment 8284
# 2024-04-09 19:57:02.672301: Processing video segment 8289
# 2024-04-09 19:57:03.641669: Processing video segment 8292
# 2024-04-09 19:57:04.701756: Processing video segment 8419
# 2024-04-09 19:57:05.938844: Processing video segment 7445
